# %% [markdown]
# 3.1 (Validating User Input)

# %%
correct_value = 0
failed_value = 0
counter = 0

for item in range(5):
    value = int(input("Enter 1 or 2 value, "))

        

    if value  == 1 or value  == 2 :
        correct_value +=1
        
    else:
        print('Invalid input, Try again')
        failed_value +=1
    


    

print('Passed:', correct_value)
print('Failed:', failed_value)
# Out:
# Invalid input, Try again
# Invalid input, Try again
# Passed: 3
# Failed: 2

# %% [markdown]
# 3.2 (What’s Wrong with This Code?)

# %%
a = b = 7

print('a =', a, '\nb =',b)
# Out:
# a = 7
# b = 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for row in range (10):
    for column in range(10):
        print('<' if row % 2 == 1 else '>',end='')
    print('')
# Out:
# >>>>>>>>>>
# <<<<<<<<<<
# >>>>>>>>>>
# <<<<<<<<<<
# >>>>>>>>>>
# <<<<<<<<<<
# >>>>>>>>>>
# <<<<<<<<<<
# >>>>>>>>>>
# <<<<<<<<<<

# %% [markdown]
# 3.4 (Fill in the Missing Code) A square number is the result of multiplying an integer
# by itself, for example, 4, 9, and 16. Complete the code below to demonstrate this property
# for the number 9:
# for ***:
# for ***:
# print('0', end='')
# print()
# replace the *** so that executing the code displays the following output:
# 000
# 000
# 000

# %%
for i in range(3):
    for k in range(3):
        print('0', end='')
    print()
# Out:
# 000
# 000
# 000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('Enter two integers and I will tell you', 
      'the relationships they satisfy.')



# read first integer
number1 = int(input('Enter first integer: '))

# read second integer
number2 = int(input('Enter second integer: '))

if number1 == number2:
    print(number1, 'is equal to',number2)

else:
    print(number1,'is not eqaul to',number2)

if number1 < number2:
    print(number1,'is less than',number2)

else:
    print(number1,'is greater than',number2)

if number1 <= number2:
    print(number1,'is less than or equal to',number2)

else:
    print(number1,'is greater than or equal to',number2)
# Out:
# Enter two integers and I will tell you the relationships they satisfy.
# 2 is not eqaul to 3
# 2 is less than 3
# 2 is less than or equal to 3

# %% [markdown]
# 3.6 (Turing Test)

# %%
print('Turing Test')


user = input('What is your problem ?')

user = input('Have you had this problem before Yes,No ?')

if user == 'Yes':
    print('Well, you have it again')

else:
    print('Well, you have it now')
# Out:
# Turing Test
# Well, you have it again

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import statistics 
import math
infections = []
total_infections  = 0

for day in range (2):
    
    daily_infections = int(input('Enter Number of reported infections for day '+str(day+1)))
    total_infections += daily_infections
    infections.append(daily_infections)



# Calculate average, smallest, largest values
average_infections = total_infections / 2
smallest_infections = min(infections)
largest_infections = max(infections)

# Output the results
print("Total reported infections in the week: ", total_infections)
print("Average daily infections in the week: ", average_infections)
print("Day with the smallest number of infections: ", smallest_infections)
print("Day with the largest number of infections: ", largest_infections)
print(infections)
print(statistics.mean(infections))
print(statistics.median(infections))
print(statistics.mode(infections))
# Out:
# 3

# %% [markdown]
# 3.9 (Calculating Time) In Exercise 2.11 , you wrote a script that calculated the number
# of hours, minutes, and remaining seconds based on the number of seconds received
# through user input. Reimplement your script to use a loop that in an iterative process
# "picks off' the hours, minutes, and remaining seconds using the // and % operators.

# %%
#Get total seconds from the user
total_seconds = int(input("Enter the total seconds: "))

hours = 0
minutes = 0
seconds = 0

while total_seconds > 0:
    # Determine how many hours
    if total_seconds >= 3600:
        hours = total_seconds // 3600
        total_seconds = total_seconds % 3600

    # Determine how many minutes
    elif total_seconds >= 60 :
        minutes = total_seconds // 60
        total_seconds = total_seconds % 60

    # Determine remaining seconds
    else:
        seconds = total_seconds
        total_seconds = 0

# Printing result
print("Hours: ", hours)
print("Minutes: ", minutes)
print("Seconds: ", seconds)
# Out:
# Hours:  277
# Minutes:  46
# Seconds:  40

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
new_hourly_Wage = 0
current_hourly_Wage = 10
percent_raise = 0.03
num_years = 1

for review in range(10):

    new_hourly_wage = current_hourly_Wage * (1+percent_raise) ** (num_years)

    print('Year ', review+1, 'raise is,', new_hourly_wage)
    
    current_hourly_Wage = new_hourly_wage

    num_years += 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Initialization
total_does = 0
total_rabbits_born = 0
months = 0

# Sentinel-controlled loop
while True:
    # Input number of does and rabbits born
    does = int(input("Enter the number of does living in the farm (enter -1 to quit): "))
    
    # If sentinel value is entered, break the loop
    if does == -1:
        break
    
    rabbits_born = int(input("Enter the number of rabbits born in the month: "))

    # Update totals
    total_does += does
    total_rabbits_born += rabbits_born
    months += 1

# Calculate average
average = total_rabbits_born / total_does

# Output result
print("The combined average number of rabbits born per doe is ", average)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("**Welcome To Triangles**")

for length in range (1):
    x = int(input("Enter angel X"))
    y = int(input("Enter angel Y"))
    z = int(input("Enter angel Z"))

    if x == y == z:
        print("This is an equilateral triangle")
    else:
        print("This is not an equilateral triangle")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input("Enter a non-negative integer: "))

sum_divi = 0

for i in range(1,n):
    if n % i == 0:
         sum_divi += i
        

if sum_divi == n:
     print(f"{n} is a perfect number.")
else:
    print(f"{n} is not a perfect number.")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
highest  = float("-inf")
second_highest = float("-inf")

for i in range (1,11):

    speed = int(input(f"Enter the speed runner {i} in m/sec: "))

    if speed > highest:
        second_highest = highest
        highest = speed
    elif speed > second_highest:
        second_highest = speed
print("\nThe fastest speed is: ", highest, "m/sec")
print("The second fastest speed is: ", second_highest, "m/sec")

# %%
for i in range(10,1,-1):
    for n in range(1,i):
        print("*",end=" ")
    print()

# %%
print("Pattern 3\n")
for i in range(1, 11):
    for j in range(10 - i):
        print(' ', end='')
    for k in range(i):
        print('*', end='')
    print()

# %%
# Pattern 4
print("Pattern 4\n")
for i in range(10, 0, -1):
    for j in range(10 - i):
        print(' ', end='')
    for k in range(i):
        print('*', end='')
    print()

# %%
x = 16
y = 16

# %%
print(id(x))
print(id(y))

# %% [markdown]
# ![Alt text](image.png)

# %%
import statistics

temp = [19.5,19.5,21.6,20.2,19.7,20.2,18.6,17.2,19.5]

mean = statistics.mean(temp)

median = statistics.median(temp)

mode = statistics.mode(temp)

print('The mean is:',mean,'\nThe median is:',median,'\nThe mode is:',mode)


temp.append(20.2)

try:
    mode = statistics.mode(temp)
    print("Mode after adding 10th day: ", mode)
except statistics.StatisticsError:
    print("No unique mode found after adding 10th day.")

# %%
print("Hi")
# Out:
# Hi
